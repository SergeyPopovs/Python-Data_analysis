# %%
import pandas as pd

# %% [markdown]
# # Работа с Pandas

# %% [markdown]
# Загрузите ваш DataFrame в переменную df и выведете на экран первые пять строк

# %%
googleplaystore_pro_df=pd.read_csv('C:/Users/Sergey/Downloads/googleplaystore_pro.csv')
googleplaystore_pro_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# Отобразите количество строк и столбцов в DataFrame

# %%
googleplaystore_pro_df.shape
# Out:
# (10841, 13)

# %% [markdown]
# # PRO часть (Не обязательна к выполнению, но желательна :))

# %% [markdown]
# Измените названия всех столбцов приведя их к нижнему регистру

# %% [markdown]
# Приведем названия столбцов к нижнему регистру

# %%
column_names=list(googleplaystore_pro_df.columns)

# %%
print(column_names)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %%
lower_column_names=[]
for word in column_names:
    lower_column_names.append(word.lower())

# %%
print(lower_column_names)
# Out:
# ['app', 'category', 'rating', 'reviews', 'size', 'installs', 'type', 'price', 'content rating', 'genres', 'last updated', 'current ver', 'android ver']

# %%
googleplaystore_pro_df.columns=lower_column_names
googleplaystore_pro_df
# Out:
#                                                      app             category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# Выведите основные статистики по категориальным столбцам. Напишите выводы о них

# %%
for column in lower_column_names:
    print(column,"_"*(15-len(column)), ":")
    print(googleplaystore_pro_df[column].describe())
# Out:
# app ____________ :
# count      10841
# unique      9660
# top       ROBLOX
# freq           9
# Name: app, dtype: object
# category _______ :
# count      10841
# unique        34
# top       FAMILY
# freq        1972
# Name: category, dtype: object
# rating _________ :
# count    9367.000000
# mean        4.193338
# std         0.537431
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max        19.000000
# Name: rating, dtype: float64
# reviews ________ :
# count     10841
# unique     6002
# top           0
# freq        596
# Name: reviews, dtype: object
# size ___________ :
# count                  10841
# unique                   462
# top       Varies with device
# freq                    1695
# Name: size, dtype: object
# installs _______ :
# count          10841
# unique            22
# top       1,000,000+
# freq            1579
# Name: installs, dtype: object
# type ___________ :
# count     10840
# unique        3
# ...

# %% [markdown]
# Выводы по статистике по категориальным столбцам:
# 1.app ____________ :
# общее кол-во заполненных строк-10841
# уникальных приложений-9660
# самое частотное приложение- Roblox (9поз.)
#
# 2.category _______ :
# общее кол-во заполненных строк-10841
# уникальных категорий-34
# самая частотная категория- Family (1972поз.)
#
# 3.rating _________ :
# общее кол-во заполненных строк-9367.000000 => 10841-9367=1474 пустых строк(>10%) => дополнить медианным значением рейтинга
# средний рейтинг-4.193338
# стандартное оклонение значений рейтинга в пределах +-0.537431
# минимальный (худший) рейтинг-1.000000
# 25% приложений имеют рейтинг 4.000000
# 50% приложений имеют рейтинг 4.300000
# 75% приложений имеют рейтинг 4.500000
# максимальный (лучший) рейтинг-19.000000 => выброс данных (max=5.0) => удалить строку/строки (проверить кол-во)
#
# 4.reviews ________ :
# общее кол-во заполненных строк-10841
# уникальное кол-во сделанных ревью-6002
# тип данных-object => перевести в тип "float" => математические операции
#
# 5.size___________
# общее кол-во заполненных строк-10841
# уникальное кол-во значений размера-462
# самый частотный размер-"Varies with device" (1695поз.) => выброс данных более 15% => удалять нельзя => заполним медианным значением
# тип данных-object => перевести в тип "float" => математические операции
#
# 6.installs _______ :
# общее кол-во заполненных строк-10841
# уникальное кол-во значений установок-22
# самое частотное кол-во установок- более 1,000,000 (встречается 1579 раз)
# тип данных-object => перевести в тип "float" => математические операции
#
# 7.type _________ :
# общее кол-во заполненных строк-10840 => 1 строка выброс данных => удалить (менее 10%)
# уникальное кол-во типов-3
# самый частотный тип- Free (встречается 10039 раз)
#
# 8.price _________ :
# общее кол-во заполненных строк-10841
# средняя цена-1.027273
# стандартное отклонение значений цены в пределах +-15.948971
# минимальная цена-0.000000
# 25% цен 0.000000
# 50% цен 0.000000
# 75% цен 0.000000
# максимальная цена-400.000000 => выброс данных/проверить кол-во => удалить строку/строки
#
# 9.content rating _ :
# общее кол-во заполненных строк-10840 => 1 строка выброс данных => удалить (менее 10%)
# кол-во уникальных значений контент рейтинга-6
# самый частотный контентный рейтинг-"Everyone"(встречается 8714 раз)
#
# 10.genres _________ :
# общее кол-во заполненных строк-10841
# кол-во уникальных жанров-120
# самый частотный жанр-"Tools" (встречается 842 раза)
#
# 11.last updated ___ :
# общее кол-во заполненных строк-10841
# кол-во уникальных дат обновления-1378
# самая частотная дата обновления-"August 3, 2018" (встречается 326 раз)
#
# 12.current ver ___ :
# общее кол-во заполненных строк-10833 => 8 строк выброс данных => удалить (менее 10%)
# кол-во уникальных уникальных текущих версий-2832
# самая частотная текущая версия-"Varies with device" (встречается 1459 раз) выброс данных более 10% => удалять нельзя => заполним медианным значением
#
# 13.android ver ___ :
# общее кол-во заполненных строк-10838 => 3 строки выброс данных => удалить (менее 10%)
# кол-во уникальных уникальных версий андроид-33
# самая частотная версия андроид-"4.1 and up" (встречается 2451 раз)
#
# Резюме: при анализе столбцов выявили выбросы данных, некоторые из них менее 10% от общей датамассы.Однако, при удалении тех или иных данных необходимо помнить,что весь датасет можно сократить максимум на 10%,не более.

# %% [markdown]
# Выведите на экран часть датафрейма, который соответствует условию: `приложение из категории искусства и дизайна` И `с рейтингом больше 4.5`

# %% [markdown]
# Найдем в столбце category категорию "Искусство и дизайн"

# %%
googleplaystore_pro_df['category'].value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       85
# AUTO_AND_VEHICLES        85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
Наша категория "ART_AND_DESIGN". Выведем на экран приложения из данной категории с рейтингом больше 4.5.
# Out:
#   Cell In[14], line 1
#     Наша категория "ART_AND_DESIGN". Выведем на экран приложения из данной категории с рейтингом больше 4.5.
#          ^
# SyntaxError: invalid syntax

# %%
googleplaystore_pro_df[(googleplaystore_pro_df.category=='ART_AND_DESIGN')&(googleplaystore_pro_df.rating>4.5)]
# Out:
#                                                     app        category  \
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 9                         Kids Paint Free - Drawing Fun  ART_AND_DESIGN
# 13                                Mandala Coloring Book  ART_AND_DESIGN
# 16         Photo Designer - Write your name with shapes  ART_AND_DESIGN
# 19                                         ibis Paint X  ART_AND_DESIGN
# 22              Superheroes Wallpapers | 4K Backgrounds  ART_AND_DESIGN
# 24                          HD Mickey Minnie Wallpapers  ART_AND_DESIGN
# 25                           Harley Quinn wallpapers HD  ART_AND_DESIGN
# 26                        Colorfit - Drawing & Coloring  ART_AND_DESIGN
# 34                                      I Creative Idea  ART_AND_DESIGN
# 36       UNICORN - Color By Number & Pixel Art Coloring  ART_AND_DESIGN
# 38                       PIP Camera - PIP Collage Maker  ART_AND_DESIGN
# ...

# %% [markdown]
# Посчитатайте какое количество игр содержится в рейтинге, используя параметр разбиения (bins) равным 100. Выведите на экран топ-10 игр по количеству в рейтинге. Напишите краткий вывод.
# То есть сначала отфильтровываете лишь игры из всего датафрейма, после чего применяете value_counts к столбцу с рейтингом используя параметр, который указан выше. И выводите первые 10 строк отсортированных по убыванию.

# %% [markdown]
# Отфильтруем игры из всего датафрейма.

# %%
googleplaystore_pro_df[googleplaystore_pro_df.category=='GAME']
# Out:
#                                 app category  rating   reviews size  \
# 1653                         ROBLOX     GAME     4.5   4447388  67M
# 1654                 Subway Surfers     GAME     4.5  27722264  76M
# 1655               Candy Crush Saga     GAME     4.4  22426677  74M
# 1656                      Solitaire     GAME     4.7    254258  23M
# 1657                 Bubble Shooter     GAME     4.5    148897  46M
# ...                             ...      ...     ...       ...  ...
# 10791             Winter Wonderland     GAME     4.0      1287  38M
# 10792        Soccer Clubs Logo Quiz     GAME     4.2     21661  16M
# 10793                     Sid Story     GAME     4.4     28510  78M
# 10803  Fatal Raid - No.1 Mobile FPS     GAME     4.3     56496  81M
# 10804                  Poker Pro.Fr     GAME     4.2      5442  17M
#
#              installs  type  price content rating  \
# 1653     100,000,000+  Free    0.0   Everyone 10+
# ...

# %% [markdown]
# Применим "value_counts" к столбцу с рейтингом используя параметр bin=100 и выведем первые 10 строк отсортированных диапазонов по убыванию.

# %%
game_df=googleplaystore_pro_df[googleplaystore_pro_df.category=='GAME']['rating'].value_counts(bins=100).reset_index().head(10)
game_df
# Out:
#           index  rating
# 0  (4.48, 4.52]     174
# 1   (4.36, 4.4]     166
# 2  (4.28, 4.32]     151
# 3   (4.56, 4.6]     121
# 4   (4.16, 4.2]     115
# 5  (4.08, 4.12]      72
# 6  (4.68, 4.72]      67
# 7   (3.96, 4.0]      55
# 8   (3.76, 3.8]      41
# 9  (3.88, 3.92]      35

# %% [markdown]
# Получили диапазон рейтинга самых популярных игр (4.48, 4.52). Выведем топ 10 наиболее популярных игр по рейтингу (также добавим критерий "installs"). Предварительно "очистим" столбец "installs" от '+' и ','.

# %%
#отключим предупреждение "SettingWithCopyWarning message"
pd.options.mode.chained_assignment = None
top_df=googleplaystore_pro_df[(googleplaystore_pro_df.category=='GAME')&(googleplaystore_pro_df.rating>4.48)]
#переведем столбец installs из object в тип float
top1_df={}
top1_df['f'] = top_df['installs'].copy()
top1_df['f'] = top1_df['f'].str.replace(',', '', regex=True).str.replace('+', '', regex=True).astype(float)
top_df['installs_f']=top1_df['f'].copy()
top_df.sort_values(by=['rating','installs_f'], ascending=[False,False]).head(10)
# Out:
#                                                app category  rating reviews  \
# 5822   Flippy Axe : Flip The Knife & Axe Simulator     GAME     5.0       7
# 7698                                     CP Trivia     GAME     5.0       5
# 10721                            Mad Dash Fo' Cash     GAME     5.0      14
# 5795                              Axe Champs! Wars     GAME     5.0       8
# 9056                   Santa's Monster Shootout DX     GAME     5.0       4
# 7402                          Trovami se ci riesci     GAME     5.0      11
# 7466                                        211:CK     GAME     5.0       8
# 9265                                      EC Mover     GAME     5.0       5
# 10776                             Monster Ride Pro     GAME     5.0       1
# 6700                              Brick Breaker BR     GAME     5.0       7
#
#        size installs  type  price content rating  genres        last updated  \
# ...

# %% [markdown]
# Вывод: Самые популярные игры в разрезе рейтинг/кол-во скачиваний:
# 1. Flippy Axe : Flip The Knife & Axe Simulator
# 2. CP Trivia
# 3. Mad Dash Fo' Cash
# 4. Axe Champs! Wars
# 5. Santa's Monster Shootout DX
# 6. Trovami se ci riesci
# 7. 211:CK
# 8. EC Mover
# 9. Monster Ride Pro
# 10. Brick Breaker BR
# Самые популярные жанры: аркады и гонки (arcade/racing). 80% игр бесплатны к скачиванию. Размер всех игр не превышает 40 мгб.

# %% [markdown]
# Создайте функцию , которая будет применена к столбцу рейтинг методом `apply()`.
# Функция должна принимать строку с рейтингом и возвращать:
#  - High rating, если рейтинг больше или равен 4.5
#  - Middle rating, если рейтинг между 3.8 и 4.5
#  - Low rating, если рейтинг меньше 3.8
# Результат работы функции запишите в новый столбец с названием `categorical_rating`

# %%
def rate_eval(rating):
    if rating>=4.5:
        return "High rating"
    elif rating>3.8 and rating<4.5:
        return "Middle rating"
    elif rating<3.8:
        return "Low rating"
    else:
        return "no data"

# %%
googleplaystore_pro_df['rating_evaluation']=googleplaystore_pro_df['rating'].apply(rate_eval)
googleplaystore_pro_df
# Out:
#                                                      app             category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# Выведите кол-во уникальных значений в столбцах отсортированных по убыванию на экран:

# %%
display(googleplaystore_pro_df.value_counts())
# Out:
# app                                                 category          rating  reviews  size                installs      type  price  content rating  genres                       last updated        current ver                              android ver         rating_evaluation
# CBS Sports App - Scores, News, Stats & Watch Live   SPORTS            4.3     91031    Varies with device  5,000,000+    Free  0.00   Everyone        Sports                       August 4, 2018      Varies with device                       5.0 and up          Middle rating        4
# Nick                                                ENTERTAINMENT     4.2     123279   25M                 10,000,000+   Free  0.00   Everyone 10+    Entertainment;Music & Video  January 24, 2018    2.0.8                                    4.4 and up          Middle rating        4
# ...

# %% [markdown]
# __Super-Hard задания__
#
# Решите задачу, где мы создавали свою собственную функцию, но вместо функции `def` используйте `лямбда-функцию` внутри `apply()`

# %% [markdown]
# предыдущая функция:
# def rate_eval(rating):
#     if rating>=4.5:
#         return "High rating"
#     elif rating>3.8 and rating<4.5:
#         return "Middle rating"
#     elif rating<3.8:
#         return "Low rating"
#     else:
#         return "no data"

# %%
googleplaystore_pro_df['rating_eval']=googleplaystore_pro_df['rating'].apply(lambda rating: "High rating" if rating>=4.5 else("Low rating" if rating<3.8 else "Middle rating")) 
googleplaystore_pro_df
# Out:
#                                                      app             category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# Изучите функцию `transform` в документации Pandas. Примените её к датафрейму, который будет заранее сгруппирован по столбцу `category`. С помощью фукнции `transform` найдите средний `rating` по каждой категории и запишите в столбец с названием `mean_cat_rating`. Кол-во строк в получившемся новом столбец должно быть таким же, как и в исходном датафрейме

# %%
googleplaystore_pro_df['mean_cat_rating']=googleplaystore_pro_df.groupby(by='category')['rating'].transform('mean')
googleplaystore_pro_df
# Out:
#                                                      app             category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# Создайте функцию , которая будет применена к столбцу `last updated` и возвращать из него число месяца, если число месяца вернуть из строки невозможно, то верните вместо этого строку с значением `miss_date`.\
# Запишите полученный столбец в датафрейм , название столбцу дайте `day_of_update`.
#
# Если вы столкнётесь с некоторой ошибкой , которую вам выдаст Pandas, то изучите конструкцию Python `try` \ `except`.\
# Вот псевдокод , который поможет лучше разобраться с этой конструкцией:

# %% [markdown]
#     Воспользуемся модулем для работы с датами: pd.to_datetime

# %%
from datetime import datetime
def update(last_updated):
    try: # Помещаете то, что должно выполниться внутрь try, если же внутри try появляется ошибка, то условие переключается на оператор except и выполняется всё то, что находится внутри except.
        last_updated= pd.to_datetime(last_updated)
        
        return last_updated.day
    except:
        return "miss_date"

googleplaystore_pro_df['day_of_update']=googleplaystore_pro_df['last updated'].apply(update)
display(googleplaystore_pro_df)
# Out:
#                                                      app             category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...
